# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls /content/drive/MyDrive/Video
# Out:
# Mounted at /content/drive
#  Đức.mp4    Hùng.mp4   Quân.mp4    Trường.mp4  'Việt Đức.mp4'
#  HĐức.mp4   Kiên.mp4   Tân.mp4	   Tuấn.mp4    'Xuân Anh.mp4'
#  Hiếu.mp4   Linh.mp4   Thắng.mp4   Vân.mp4

# %%
# !pip install retina-face
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14273 sha256=b27e0543b9307dca9944096b6b78ad9b4b756541d165f29a6553f6ddb3270bc5
#   Stored in directory: /root/.cache/pip/wheels/8c/17/ff/58721d1fabdb87c21a0529948cf39e2be9af90ddbe4ad65944
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %%
import cv2
import math
from retinaface import RetinaFace
import matplotlib.pyplot as plt

# %%
files = [ "Đức","Hùng","Quân","Trường","Việt Đức","HĐức","Kiên","Tân","Tuấn","Xuân Anh","Hiếu","Linh","Thắng","Vân"]
print( len(files))
for file in files:
  videoFile = f"/content/drive/MyDrive/Video/{file}.mp4"
  imagesFolder = "/content/drive/MyDrive/video to frame"
  imagesFolder1 ="/content/drive/MyDrive/detect"
  cap = cv2.VideoCapture(videoFile)
  frameRate = cap.get(5) #frame rate
  count = 0
  while(cap.isOpened()):
      frameId = cap.get(1) #current frame number
      ret, frame = cap.read()
      if (ret != True):
          break
      if (frameId % math.floor(frameRate) == 0 or frameId % math.floor(frameRate) ==  5 or frameId % math.floor(frameRate) == 10 or frameId % math.floor(frameRate) == 15 or frameId % math.floor(frameRate) == 20):
          filename = imagesFolder + f"/{file}_" +  str(int(count)) + ".jpg"
          filename1 = imagesFolder1 + f"/{file}_" +  str(int(count)) + ".jpg"
          cv2.imwrite(filename, frame)
          resp = RetinaFace.detect_faces(filename)
          faces = RetinaFace.extract_faces(img_path = filename, align = True)
          for face in faces:
            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            cv2.imwrite(filename1, face)
          count+=1
  cap.release()
  print (f"Done!{count} in {file}.mp4")
# Out:
# 14
# Done!100 in Đức.mp4
# Done!126 in Hùng.mp4
# Done!165 in Quân.mp4
# Done!0 in  Trường.mp4
# Done!105 in Việt Đức.mp4
# Done!0 in  HĐức.mp4
# Done!88 in Kiên.mp4
# Done!57 in Tân.mp4
# Done!90 in Tuấn.mp4
# Done!150 in Xuân Anh.mp4
# Done!93 in Hiếu.mp4
# Done!62 in Linh.mp4
# Done!57 in Thắng.mp4

# %%
files = ["Trường","HĐức","Vân","Linh","Thắng","Tân"]
print( len(files))
for file in files:
  videoFile = f"/content/drive/MyDrive/Video/{file}.mp4"
  imagesFolder = "/content/drive/MyDrive/video to frame"
  imagesFolder1 ="/content/drive/MyDrive/detect"
  cap = cv2.VideoCapture(videoFile)
  frameRate = cap.get(5) #frame rate
  count = 0
  while(cap.isOpened()):
      frameId = cap.get(1) #current frame number
      ret, frame = cap.read()
      if (ret != True):
          break
      if (frameId % math.floor(frameRate) == 3 or frameId % math.floor(frameRate) ==  8 or frameId % math.floor(frameRate) == 13 or frameId % math.floor(frameRate) == 18 or frameId % math.floor(frameRate) == 27):
          filename = imagesFolder + f"/{file}_0" +  str(int(count)) + ".jpg"
          filename1 = imagesFolder1 + f"/{file}_0" +  str(int(count)) + ".jpg"
          cv2.imwrite(filename, frame)
          resp = RetinaFace.detect_faces(filename)
          faces = RetinaFace.extract_faces(img_path = filename, align = True)
          for face in faces:
            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            cv2.imwrite(filename1, face)
          count+=1
  cap.release()
  print (f"Done!{count} in {file}.mp4")
# Out:
# 6
# Done!69 in Trường.mp4
# Done!43 in HĐức.mp4
# Done!77 in Vân.mp4
# Done!61 in Linh.mp4
# Done!57 in Thắng.mp4
# Done!56 in Tân.mp4
